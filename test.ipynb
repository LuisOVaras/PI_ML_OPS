# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from textblob import TextBlob

# %%
# Configurar pandas para mostrar todas las filas y columnas
pd.set_option('display.max_rows', None)  # Muestra todas las filas
pd.set_option('display.max_columns', None)  # Muestra todas las columnas
pd.set_option('display.width', None)  # Ancho de la pantalla sin truncar

# %%
# Importamos los archivos y los almacenamos como DataFrames

df_steam_games = pd.read_csv('data\output\steam_games.csv')

# %%
df_steam_games.shape
# Out:
# (28851, 9)

# %%
# Seleccionar solo las columnas "title" y "developer" y mostrar las primeras filas
subset_df = df_steam_games[['title', 'developer']]

# %% [markdown]
# #### Esto solo está hecho para tener en cuenta 100 nombres de developer y sus titulos para saber si funciona el endpoint llamado def developer para así testearlo con diferentes nombres
#
# ##### def developer(desarrolladora: str):

# %%
# Filtrar las filas con ID igual a 70
df_filtered = df_steam_games[df_steam_games['publisher'] == 'Rockstar Games']

# Mostrar el DataFrame filtrado
df_filtered.head()
# Out:
#          publisher      genres                               title  \
# 90  Rockstar Games  ['Action']                    Grand Theft Auto
# 91  Rockstar Games  ['Action']                  Grand Theft Auto 2
# 92  Rockstar Games  ['Action']                             Manhunt
# 93  Rockstar Games  ['Racing']                     Midnight Club 2
# 94  Rockstar Games  ['Action']  Max Payne 2: The Fall of Max Payne
#
#    release_date                              specs price  early_access     id  \
# 90   1998-06-30                  ['Single-player']   NaN         False  12170
# 91   1999-10-25                  ['Single-player']   NaN         False  12180
# 92   2004-04-20                  ['Single-player']  9.99         False  12130
# 93   2003-07-01  ['Single-player', 'Multi-player']  9.99         False  12160
# 94   2003-10-14                  ['Single-player']  9.99         False  12150
#
#                developer
# 90        Rockstar North
# 91        Rockstar North
# ...

# %%
df_steam_games.tail()
# Out:
#              publisher                                         genres  \
# 28846  Bidoniera Games     ['Action', 'Adventure', 'Casual', 'Indie']
# 28847  Ghost_RUS Games  ['Casual', 'Indie', 'Simulation', 'Strategy']
# 28848           Sacada                ['Casual', 'Indie', 'Strategy']
# 28849     Laush Studio              ['Indie', 'Racing', 'Simulation']
# 28850         SIXNAILS                            ['Casual', 'Indie']
#
#                           title release_date  \
# 28846              Kebab it Up!   2018-01-04
# 28847            Colony On Mars   2018-01-04
# 28848  LOGistICAL: South Africa   2018-01-04
# 28849             Russian Roads   2018-01-04
# 28850       EXIT 2 - Directions   2017-09-02
#
#                                                    specs price  early_access  \
# 28846  ['Single-player', 'Steam Achievements', 'Steam...  1.99         False
# 28847            ['Single-player', 'Steam Achievements']  1.99         False
# ...

# %%
subset_df.tail(100)
# Out:
#                                                    title  \
# 28751                                   Dungeon Siege II
# 28752                      Red Orchestra: Ostfront 41-45
# 28753                            Space Empires IV Deluxe
# 28754                                   Dangerous Waters
# 28755                                         Earth 2160
# 28756                       Half-Life Deathmatch: Source
# 28757                                      Shadowgrounds
# 28758                           Half-Life 2: Episode One
# 28759                            SiN Episodes: Emergence
# 28760                             Jagged Alliance 2 Gold
# 28761                                        X3: Reunion
# 28762                                     X2: The Threat
# 28763                 Iron Warriors: T - 72 Tank Command
# 28764                                             Uplink
# 28765                                        Xpand Rally
# ...

# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity


df_steam = pd.read_csv('data\output\steam_games.csv')

# %%
df_steam.head(10)
# Out:
#                 publisher                                             genres  \
# 0               Kotoshiro  ['Action', 'Casual', 'Indie', 'Simulation', 'S...
# 1        Making Fun, Inc.       ['Free to Play', 'Indie', 'RPG', 'Strategy']
# 2            Poolians.com  ['Casual', 'Free to Play', 'Indie', 'Simulatio...
# 3                    彼岸领域                  ['Action', 'Adventure', 'Casual']
# 4     Trickjump Games Ltd              ['Action', 'Adventure', 'Simulation']
# 5                     NaN  ['Free to Play', 'Indie', 'Simulation', 'Sports']
# 6  Poppermost Productions  ['Free to Play', 'Indie', 'Simulation', 'Sports']
# 7  Poppermost Productions  ['Free to Play', 'Indie', 'Simulation', 'Sports']
# 8               RewindApp        ['Casual', 'Indie', 'Racing', 'Simulation']
# 9                 Qucheza  ['Action', 'Indie', 'Simulation', 'Early Access']
#
#                            title release_date  \
# 0            Lost Summoner Kitty   2018-01-04
# ...

# %%
print(df_steam_games.columns)
# Out:
# Index(['publisher', 'genres', 'title', 'release_date', 'specs', 'price',
#        'early_access', 'id', 'developer'],
#       dtype='object')

# %%
print(df_items.columns)
# Out:
# Index(['user_id', 'item_id', 'item_name', 'playtime_forever',
#        'playtime_2weeks'],
#       dtype='object')

# %%
print(df_reviews.columns)
# Out:
# Index(['user_id', 'item_id', 'posted', 'recommend', 'sentiment_analysis'], dtype='object')

# %%
df_reviews = pd.read_csv("data/output/reviews.csv")
df_items = pd.read_parquet("data/output/items.parquet")
df_steam_games = pd.read_csv("data/output/steam_games.csv")

# %%
df_reviews.head(20)
# Out:
#               user_id  item_id      posted  recommend  sentiment_analysis
# 0   76561197970982479     1250  2011-11-05       True                   2
# 1   76561197970982479    22200  2011-07-15       True                   2
# 2   76561197970982479    43110  2011-04-21       True                   2
# 3             js41637   251610  2014-06-24       True                   2
# 4             js41637   227300  2013-09-08       True                   0
# 5             js41637   239030  2013-11-29       True                   0
# 6           evcentric   248820         NaN       True                   2
# 7           evcentric   370360  2015-12-04       True                   2
# 8           evcentric   237930  2014-11-03       True                   2
# 9           evcentric   263360  2014-10-15       True                   0
# 10          evcentric   107200  2014-10-15       True                   2
# 11          evcentric   224500  2014-10-15       True                   2
# ...

# %%
df_items.tail(20)
# Out:
#                    user_id  item_id                      item_name  \
# 5153189  76561198326700687   502550            Strike.is: The Game
# 5153190  76561198326700687   503010             Legends of Azulgar
# 5153191  76561198326700687   506140                    Shop Heroes
# 5153192  76561198326700687   402570                  Atlas Reactor
# 5153193  76561198326700687   508380     Amnesia: Final Revelations
# 5153194  76561198326700687   510050            You Have 10 Seconds
# 5153195  76561198326700687   510660                Big Bang Empire
# 5153196  76561198326700687   512470     The Pirate: Caribbean Hunt
# 5153197  76561198326700687   104900                 ORION: Prelude
# 5153198  76561198326700687   516510                Orake 2D MMORPG
# 5153199  76561198326700687   519170               The Journey Home
# 5153200  76561198326700687   358390                     Stargunner
# 5153201  76561198326700687   521570          You Have 10 Seconds 2
# ...
